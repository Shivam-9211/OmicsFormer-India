# %%
# print("Hello World")
# x = 5
# print(x)

# %%
# import pandas as pd

# df = pd.read_csv("../data/raw/tcga/BRCA_HumanMethylation450.csv")

# # df.head()
# df

# %%
# import os

# print(os.getcwd())

# %%
# print(df.shape)

# %%
# print(df.columns[:20])

# %%
# df.iloc[:5, :5]

# %%
# print(df.isnull().sum().sum())

# %%
# df.describe()

# %%
# import pandas as pd

# df2 = pd.read_csv(
#     "../data/raw/tcga/BRCA_HiSeqV2.csv")

# print(df2.shape)
# print(df2.columns[:10])
# df2.head(20)

# %%
# import pandas as pd

# df2 = pd.read_csv(
#     "../data/raw/tcga/BRCA_mc3_gene_level.csv")

# print(df2.shape)
# print(df2.columns[:10])
# df2.head()

# %%
# meth = pd.read_csv(
#     "../data/raw/tcga/BRCA_HumanMethylation450.tsv.gz",
#     sep="\t"
# )

# meth = meth.set_index("sample")

# meth = meth.T

# meth.index.name = "Sample_ID"

# meth.reset_index(inplace=True)

# %%
# import pandas as pd

# df = pd.read_csv(
#     "../data/raw/tcga/BRCA_HumanMethylation450.tsv.gz",
#     sep="\t",
#     nrows=5
# )

# print(df.shape)
# print(df.columns[:10])
# df.head()

# %%
# print(df.columns.tolist())

# %%
# import pandas as pd

# df = pd.read_csv(
#     "../data/raw/tcga/BRCA_HumanMethylation450.tsv.gz",
#     sep="\t"
# )

# print(df.shape)

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\shiva\OmicsFormer-India\data\merged\methylation.tsv",
    sep="\t",
    nrows=0
)

df1 = pd.read_csv(r"C:\Users\shiva\OmicsFormer-India\data\merged\methylation.tsv",
    sep="\t",
    usecols=[0]
)

print(df.shape)

print(df1.shape)
# Out:
# (0, 2656)
# (486427, 1)

# %%
df = pd.read_csv(
    r"C:\Users\shiva\OmicsFormer-India\data\merged\methylation.tsv",
    sep="\t",
    nrows=5
)

print(df.head())
print(df.columns[:10])
# Out:
#   Composite Element REF  TCGA-AQ-A0Y5-01A  TCGA-EW-A2FW-01A  TCGA-C8-A274-01A  \
# 0            cg00000029          0.123206          0.070247          0.095459
# 1            cg00000108          0.955195          0.898010          0.973301
# 2            cg00000109          0.924968          0.936458          0.926613
# 3            cg00000165          0.673627               NaN          0.891222
# 4            cg00000236          0.901612          0.803841          0.942629
#
#    TCGA-AC-A62V-01A  TCGA-B6-A0IK-01A  TCGA-E2-A1L7-01A  TCGA-E9-A247-01A  \
# 0          0.149745          0.213110          0.239587          0.063008
# 1          0.962013          0.965753          0.967329          0.976577
# 2          0.929127          0.925687          0.953052          0.908876
# 3               NaN          0.766033          0.331990          0.859703
# 4          0.930383          0.902132          0.924075          0.933446
#
# ...

# %%
df = pd.read_csv(
    r"C:\Users\shiva\OmicsFormer-India\data\merged\methylation.tsv",
    sep="\t",
    usecols=[0]
)

print(df.tail())
# Out:
#        Composite Element REF
# 486422             rs9363764
# 486423              rs939290
# 486424              rs951295
# 486425              rs966367
# 486426             rs9839873
